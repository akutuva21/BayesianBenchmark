# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

ks_df = pd.read_csv("results/long_Calcium_Oscillate_ks_data.csv", index_col=0)
ks_df
# Out:
#         Param   Method     KS
# 1          k1  PT-MCMC  1.000
# 2          k1  PT-MCMC  0.999
# 3          k1  PT-MCMC  1.000
# 4          k1  PT-MCMC  0.999
# 5          k1  PT-MCMC  1.000
# ...       ...      ...    ...
# 374858  dummy      PMC  1.000
# 374859  dummy      PMC  1.000
# 374860  dummy      PMC  1.000
# 374861  dummy      PMC  1.000
# 374862  dummy      PMC  1.000
#
# [370620 rows x 3 columns]

# %%
plt.figure(figsize=(12,4), dpi=600)
hueorder=["PT-MCMC", "SMC", "PMC"]
sns.boxplot(data=ks_df, x="Param", hue="Method", y="KS", showfliers=True, hue_order=hueorder)
plt.xticks(rotation=0);
plt.ylabel("Two-Way Kolmogorov-Smirnov Statistic")
plt.xlabel("Parameter")
#plt.title(shorthand)
#plt.xticks(plt.gca().get_xticks(), ["$\kappa_A$","$k_2$","$k_3$","$k_4$","$k_5$","dummy"])
plt.axhline(y=0.05, linestyle="--", color="r", lw=2);
plt.legend(loc="upper right")
